# %% [markdown]
# # Link para modificar el PPT
#
# Con modelo inicial: https://gamma.app/docs/Salimos-Hoy-vwkn7o7m52pl2ka
#
# Con modelo inicial y final: https://gamma.app/docs/Salimos-Hoy-Modelo-final-ghk9ruqlo70r0ah
